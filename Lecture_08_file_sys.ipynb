# %%
from IPython.display import Image

# %% [markdown]
# ### Review of lecture 7
#
# In lecture 7 we learned about  NumPy ndarrays

# %% [markdown]
# ###  In this lecture we will:
#
# - Learn about computer file systems,
#
# - UNIX commands from within a Jupyter Notebook
#
# - Learn about the concept of **PATH**
#
# - UNIX commands from a command line.
#
# - Learn how to run python scripts from the command line.

# %% [markdown]
# Today, we'll take a  break from programming in Python and discuss file systems, paths, and the command line. Why?  Because whenever you import an image, document, or spreadsheet into the Jupyter notebook you have to tell Jupyter where in the computer the file is located. Moreover, there are many command line functions that come in handy.  For example, you can take a quick peek at a file before you import it into the notebook.  And, you can also run all of the programs we are writing as command line scripts so, in principle,  you can run them outside the notebook from anywhere on your computer.
#
#
# ###  File systems
#
# The organization of computers are based on a _file system_. The file system is hierarchical, so at the top you'll find the _root directory_ or for Mac and PC users, a _folder_. The root directory contains files and other folders which may also contain  files and  folders and etc. This continues, resulting in a tree of files and folders that make up the file system. The following figure is an example of a computer's file system:

# %%
Image(filename='Figures/FileSystem.jpg')

# %% [markdown]
# You are probably familiar with the images like that to the left. The text to the right shows the exact same thing - but from your computer's (and Unix geeks) viewpoint. Both the image to the left and the text to the right show you how to access the folder  "Desktop".  On the left, you access the folder "Desktop" by clicking on 'icons' that represent different folders and sub-folders until you arrive at  "Desktop". Later in this lecture, we'll show you how to access the same folder using its **path** (the text to the right).

# %% [markdown]
# ### Survival UNIX commands
#
# Macs and PCs both have functions that can be called from a _command line_, such as listing the contents of a folder or file, creating new folders, changing permissions on files or folders, combining the contents of files, moving files and folders around, and so on.  These commands are to the operating system, not to the Python interpreter.
#
# Before we get to using an actual command line, we can execute many operating system commands from within a Jupyter notebook.   To signal to Jupyter that your commands are not for Python but for the operating system, you may type a "!" (bang) in front of the command.  [It isn't actually a requirement, but it does help separate what is a command line command versus what is a python script.
#
# Let's learn our first UNIX command, which lists the contents of a directory, **ls**.   [Note that your results may vary.]

# %%
# !ls
# Out:
# Figures                   Lecture_08_file_sys.ipynb myfile.txt

# %% [markdown]
# Another useful command is **mkdir** which creates a new directory.  Please note that _directory_ means the same thing as _folder_.  It is just that in a graphical operating system  with icons, the term _folder_ makes sense.  They look like folders. Whereas to the operating system, they are traditionally referred to as _directories_.  Never mind!

# %%
# !mkdir MYNEWDIRECTORY

# %% [markdown]
# To see if that worked, list the contents again:

# %%
# !ls
# Out:
# Figures                   MYNEWDIRECTORY
# Lecture_08_file_sys.ipynb myfile.txt

# %% [markdown]
# And sure enough, there it is.   The command **rmdir** deletes a directory

# %%
# !rmdir MYNEWDIRECTORY

# %% [markdown]
# Make sure it was removed:

# %%
# !ls
# Out:
# Figures                   Lecture_08_file_sys.ipynb myfile.txt

# %% [markdown]
# ### Practice with directories
#
# - Create another  directory called **Practice**.
# - List the contents of the current directory.
# - Remove the directory **Practice**.
# - List the contents of the current directory again.
# - Open the text file called **myfile.txt** and add your name to it.
# - Save **myfile.txt**

# %% [markdown]
# We can list the contents of a file with the UNIX command,  **cat**  (which  comes from concatenate).

# %%
# !cat myfile.txt
# Out:
# Hanna Asefaw

# %% [markdown]
# Usually, the output of **cat** is sent to the screen, but UNIX has tricky ways of redirecting output to other files.  For example, if we  combine **cat** with the symbol  **>** we can  _redirect_ the output to another file, instead of to the screen:

# %%
# !cat myfile.txt >newfile.txt
# !ls
# Out:
# Figures                   myfile.txt
# Lecture_08_file_sys.ipynb newfile.txt

# %% [markdown]
# So what did we create? We created a copy of **myfile.txt** called **newfile.txt**.  If you repeat the command, you will overwrite the existing output file.
#
# To append to the end of a file, we use the symbol **>>**:

# %%
# !cat myfile.txt >>newfile.txt

# %% [markdown]
# ### Practice with simple commands from within a notebook
#
# - Look at **newfile.txt** with **cat**.  See how it is doubled?
# - List the contents of your working  directory and redirect the output to a file called **directory.txt**.
# - Use **cat** to read the contents of the file  **directory.txt** (ensure that the contents of the file are the same as the output for **ls**)

# %% [markdown]
# We can delete any individual file with the **rm** command.

# %%
# !rm newfile.txt

# %% [markdown]
# There are a few other useful redirect symbols:  **<**, and **|**.  The first, **<**, takes the contents of the argument and redirects it into the command.  The second, **|**, **pipe**,takes the output of the first command and 'pipes' it to a second.  So we could do:

# %%
# !cat myfile.txt |cat
# Out:
# Hanna Asefaw

# %% [markdown]
# ... which is a little silly as it just does the same thing as the first command, but you don't know any other commands right now so...

# %% [markdown]
# ### Concept of path
#
# So far, we have just been looking at directories in our working directory (the one with this notebook in it) and subdirectories within the working directory.  Earlier in the lecture you were shown a figure with icons on the left and text on the right.  The text to the right was a series of directories separated by '/'.  These are the _paths_ to those files. A _path_ is the unique location of a file or a directory in a file system of an OS.
#
#
# Now let's take a detour and learn how to embed figures directly into a Jupyter notebook. You saw this in several lectures, but were told to ignore it.  Now you are ready to learn more about it.   The **Image** class in the module **Ipython.display** allows us to do this. We imported **Image** from **Ipython.display** in the first cell of this lecture. This allows us to embed many digital image types (png, jpg...)  into a  Jupyter notebook.
#
# The _path_ to the figure we want to display is "Figures/FileSystem.jpg" which tells the operating system to look for a folder called "Figures" and the file in it called "FileSystem.jpg".  This is a _relative path_ with respect to the directory that the notebook is in.

# %%
Image(filename='Figures/FileSystem.jpg')

# %% [markdown]
# But the _paths_ in this figure are _absolute paths_ which uniquely define the location of the file or directory from anywhere on the computer.   The _relative paths_  are handy short cuts.   For example, we can  refer to a directory above the current directory without knowing what that is necessarily, we use these conventions:
#
# ./  is the current directory
#
# ../ is the one above
#
# ../../ is the one above that
#
# and so on.

# %% [markdown]
# So... to look the contents of the directory above the working directory, we just do this:

# %%
# !ls ../ # your results will vary!
# Out:
# Lecture_01 Lecture_03 Lecture_05 Lecture_07
# Lecture_02 Lecture_04 Lecture_06 Lecture_08

# %% [markdown]
# Instead of using 'relative' directories, it is often desirable to refer to directories in an absolute sense, i.e., relative to the _root_ directory '/'.
#
# To find out what the _absolute path_ for your current directory, use **pwd** for 'print working directory':

# %%
# !pwd
# Out:
# /Users/ltauxe/Dropbox/4Hanna/SIO113_2018/Lecture_08

# %% [markdown]
# One last thing.  To refer your home directory,  just use the short cut **~**:

# %%
# !ls ~
# Out:
# AnacondaProjects     Programs             logs
# Applications         Public               personal_stuff
# Creative Cloud Files Python               profiles.bin
# Cubit-13.0           Send Registration    reprints
# Desktop              Sites                samples.txt
# Documents            SpareRoom            sites.txt
# Downloads            TeXShop              slidingrock.csv
# Dropbox              VirtualBox VMs       specimens.txt
# Google Drive         anaconda             src
# Library              bin                  sync_from
# MagIC                chart.txt            sync_log
# Meetings_2017        demag_orient.txt     sync_to
# Movies               enthought            texput.log
# Music                igrf2016.0.jpg       tmp
# Pdfs                 locations.txt        webpasswords
# Pictures             log4j

# %% [markdown]
# I guess I should clean up my Desktop!

# %% [markdown]
# ### The _command line_
#
# We were typing in commands to the operating system through our notebook, but there is another way of interacting with the operating system.   A _Terminal window_ provides a _command line interface_ in which you can type commands to the operating system.
#
# You may have been using the Canopy terminal window to launch Jupyter notebooks (found under Tools in the Canopy application) and that works just fine.
# But you  can also open a terminal window through the program **Terminal** on MacOSx or **cmd** on PCs.

# %%
Image(filename='Figures/CommandLine.jpg')

# %% [markdown]
# Let's open a terminal window (command prompt).

# %%
Image(filename='Figures/terminal.png')

# %% [markdown]
# The _terminal window_ allows you to interact with the operating system through text based commands. All of the commands we used in this notebook (and more!), can be done on the command line instead.  For example, when you fire up a terminal window, you are by default in your **home** directory (in MacOS UNIX,  that would be **/Users/YOURUSERNAME**).
#
#  You can verify this, by typing **pwd** on the command line when you open your terminal window.
#
#
#
# At times, we need to move around in the file system.   You can move from directory to directory with the  command **cd** (which is short for _change directories_).
#
#
#
# This command, **cd**, doesn't work in the notebook but it DOES on the command line.

# %% [markdown]
# One last command- after you change directories to your class directory, you can launch jupyter from the command line with:
#
# $jupyter notebook
#
# where the "$" is your command line prompt.
# You will get a listing of all the notebooks in the current directory and you can launch them by clicking on them.

# %% [markdown]
# ### Practice UNIX on your command line
#
# - Open up a terminal window.
# - Print out your current directory with **pwd**.
# - Use **mkdir** to create a new folder
# - **cd** into that folder
# - Use **cat** to write your name into a file called **myfile.txt** using the syntax:
#     - **cat > myfile.txt**
#     - Hanna Asefaw [type in your own name here!]
# - To finish the task, you must press on the **control** key and 'D' at the same time.
# - Use **cat** again (with no redirect) to see the contents of your file.

# %% [markdown]
# ### Command line python scripts
#
# As mentioned in the beginning of the lecture, you can run all the little programs you have been (and will be) writing, directly from the command line.  Here's one way to do that:
#
# - copy the code block below into a text file.  (Re)name it to 'hello.py'.  Then on your command line (from the same directory), type:
#
# **python hello.py**

# %%
print ("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# To run the program on a Mac without the **python** command first, you need to do a few things.
#
# 1) you have to put this line at the top of the script:
#
# #!/usr/bin/env python
#
# It won't hurt you on a PC, it just isn't necessary.
#
# 2) The script must be _executable_.  To find out whether a particular script is _executable_, type:
#
# ls -al YOURSCRIPTNAME:
#
# here it is in the notebook:

# %%
# !ls -al hello.py
# Out:
# ls: hello.py: No such file or directory

# %% [markdown]
# The '-rw-r--r--@' string at the front indicates who can do what with the script.  The first three letters '-rw' say that the 'user' (me) can read and write (but not execute) the script.  The next three are for the 'group' and the third are for anyone (all).
#
# To make it executable, I need to use the Unix command: **chmod** to set the permissions.  To make it executable for everyone, I type:
#
# chmod a+x
#
# where the 'a' means all and the 'x' means 'executable'.

# %%
# !chmod a+x hello.py
# !ls -al hello.py
# Out:
# -rwxr-xr-x@ 1 ltauxe  staff  22 May 20 16:16 hello.py

# %% [markdown]
# see how everybody has an 'x' now?

# %% [markdown]
# 3) The last  thing you have to worry about is that the directory containing the script must be in your **PATH**.   We have been talking about _paths_ (all lower case), but **PATH** is an environment variale on Unix-like operating systems and also DOS (what is used by PCs) specifying a set of directories where the operating system looks for executable programs.   So to run a program it must be in your **PATH**. And to run a Python program from anywhere, it must be in your **PYTHONPATH**.
#
# You can find out what your **PATH** is, by typing **echo $PATH** on the command line (or in the notebook as shown here):

# %%
# !echo $PATH # your results will definately vary!
# Out:
# /Users/ltauxe/anaconda/bin:/Users/ltauxe/anaconda/bin:/usr/local/Cellar/cmake/3.9.0/bin:/Users/ltauxe/bin:/Users/ltauxe/Programs/PmagPy/GIT/PmagPy/pmagpy:/Users/ltauxe/Programs/PmagPy/GIT/PmagPy/programs/conversion_scripts2/:/Users/ltauxe/Programs/PmagPy/GIT/PmagPy/programs/conversion_scripts/:/Users/ltauxe/Programs/PmagPy/GIT/PmagPy/programs:/Users/ltauxe/Programs/PmagPy/GIT/PmagPy:/opt/local/bin:/opt/local/sbin:/usr/local/bin:/usr/bin:/bin:/usr/sbin:/sbin:/opt/X11/bin:/usr/texbin:/Library/TeX/texbin:/Applications/GMT-5.3.1.app/Contents/Resources/bin

# %% [markdown]
# By default, your working directory will not be in your path (some security reason), so to run a script that is in your working directory, you must either put it in your **PATH** (not recommended) or use the full path name or the relative path name,  e.g.,
#
# ./hello.py
#
#
#
#
#
# Changing your **PATH** depends a lot on your particular operating system.  Most recent Macs set the path in a hidden file in your home directory called **.bash_profile**.  I recommend that you put all your **Python** scripts in some directory (say, **Python**) in your user directory.  Then you can put these lines in your **.bash_profile** file (for example using **cat>>.bash_profile**).
#
#
# export PYTHONPATH=$PYTHONPATH:~/Python
#
# (followed by control-D when using **cat**).
#
# When you open a new terminal window, your PATH environment variable should be set properly.  If it is, you can use your python scripts from any directory and also import them into a Jupyter notebook.

# %% [markdown]
# ### More practice with command lines
# - Find your command line and make a file with the directory listing of your current directory in it.
# - Make a folder called _Practice_
# - Move the file directory.txt to the folder Practic
#     - use the command:
#        **mv** _oldfilepath_ _newfilepath_
# - Remove the directory Practice (remember it must be empty).
# - Print out your current directory
# - use **cat > YOURSCRIPT.py** to make a script. (to finish, hold down control and D  at the same time).
# - Run your script with **python YOURSCRIPT.py**
# - Edit your script to include the #!/usr/bin/env python  line at the top
# - use **chmod** to make the script executable
# - execute your script from the command line.

# %% [markdown]
# Finally, this is a very handy website for learning more about how to use Jupyter notebooks in general: https://www.dataquest.io/blog/jupyter-notebook-tips-tricks-shortcuts/
